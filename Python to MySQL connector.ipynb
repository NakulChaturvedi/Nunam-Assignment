# %%
import mysql.connector

mydb= mysql.connector.connect(
host= "127.0.0.1",
user= "root",
password= "Nakul@0104")

print(mydb)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x000002360C957A60>

# %%
import mysql.connector

mydb= mysql.connector.connect(
host= "localhost",
user= "root",
password= "Nakul@0104",
database= "data_fetching")

# %%
mycursor= mydb.cursor()
mycursor.execute("select * from deliverable")

# %%
myresult= mycursor.fetchall()

for x in myresult:
    print(x)
# Out:
# (5308, 900.6, 3.9589, 1175.178, '11-15-2019 20:57:05')
# (5329, 900.6, 3.9605, 1180.455, '11-15-2019 21:07:00')

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(2,1),
                       subplot_kw=dict(polar=True))
ax.set(title="State of Health (5308)")
ax.set_axis_off()
cell = ['5308', 'rest']
 
data = [99.7, 0.3]

fig = plt.figure(figsize=(6, 4))
plt.pie(data, labels=cell)
 
plt.show()

# %%
fig, ax = plt.subplots(figsize=(2,1),
                       subplot_kw=dict(polar=True))
ax.set(title="State of Health (5329)")
ax.set_axis_off()
cell = ['5329', 'rest']
 
data = [94.08, 5.02]

fig = plt.figure(figsize=(6, 4))
plt.pie(data, labels=cell)
 
plt.show()
